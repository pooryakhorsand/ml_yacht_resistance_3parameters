# %% [markdown]
# # Import Libraries and Set Up

# %% [markdown]
# This cell loads all necessary packages for data handling, visualization, and machine learning. It also reflects the paper’s emphasis on data preprocessing and feature engineering.

# %%
# Data Handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning Models and Tools
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from math import sqrt

from sklearn.model_selection import GridSearchCV, cross_val_predict, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from math import sqrt
import warnings

# %% [markdown]
# # Load and Preprocess the Dataset

# %% [markdown]
# This cell loads the Delft University dataset and removes extraneous hydrostatic features. As described in Section 2.1 of your paper, only the necessary hydrodynamic parameters are retained.

# %%
# Load the dataset (update the file path as needed)
df = pd.read_csv(r'C:\Users\poory\Desktop\New folder\expanded_data.csv')

# Display the first few rows
df.head()

# Remove extraneous hydrostatic features not essential for resistance prediction
df.drop(['KBc','BcMc','KMc','KB','BM','KM', 'It', 'IL'], axis=1, inplace=True)

# %% [markdown]
# # Visualize Missing Values and Data Distributions

# %% [markdown]
# Following the methodology in Section 2.1, this cell calculates and plots the percentage of missing values and uses boxplots and KDE plots to assess outliers and normalized distributions.

# %%
# --- Missing Values Bar Plot ---
nan_percent = df.isna().mean() * 100
plt.figure(figsize=(12, 7), dpi=300)
ax = nan_percent.plot(kind='bar', color='royalblue', edgecolor='navy', width=0.8)
plt.title("Percentage of Missing Values per Column", fontsize=14, pad=20)
plt.xlabel("Columns", fontsize=12, labelpad=10)
plt.ylabel("NaN Percentage (%)", fontsize=12, labelpad=10)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)
for p in ax.patches:
    ax.annotate(f"{p.get_height():.1f}%", 
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5),
                textcoords='offset points', fontsize=9)
plt.tight_layout()
plt.savefig('missing_values_plot.png', dpi=300, bbox_inches='tight', transparent=False)
plt.show()

# --- Boxplot for Outlier Analysis ---
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
plt.figure(figsize=(14, 10), dpi=300)
ax = sns.boxplot(data=df[numeric_cols], orient='h', palette='Set3', width=0.7)
plt.title("Distribution of Hydrodynamic Parameters with Outliers", fontsize=14, pad=20, fontweight='bold')
plt.xlabel("Value (Normalized Units)", fontsize=12, labelpad=10)
plt.ylabel("Parameters", fontsize=12, labelpad=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='x', linestyle=':', alpha=0.4)
sns.despine(left=True)
plt.tight_layout()
plt.savefig('boxplot_outliers.png', dpi=300, bbox_inches='tight', transparent=True)
plt.savefig('boxplot_outliers.pdf', bbox_inches='tight')
plt.show()

# --- KDE Plot with ±3σ Outlier Thresholds ---
df_normalized = (df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std()
plt.figure(figsize=(14, 8))
for col in numeric_cols:
    sns.kdeplot(df_normalized[col], label=col, fill=True, alpha=0.3)
plt.axvline(-3, color='red', linestyle='--', label='μ - 3σ (Outlier Threshold)')
plt.axvline(3, color='red', linestyle='--', label='μ + 3σ (Outlier Threshold)')
plt.title("Normalized Distributions with ±3σ Outlier Thresholds")
plt.xlabel("Normalized Values (μ = 0, σ = 1)")
plt.ylabel("Density")
plt.legend()
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Correlation Matrix Heatmap

# %% [markdown]
# As described in Section 2.2, the correlation analysis identifies perfect correlations between Bmax and BWL, and between D and T. This visualization supports your subsequent regression models.

# %%
# Compute and plot the correlation matrix
corr_matrix = df.corr()
plt.figure(figsize=(12, 10), dpi=300)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Regression 1 – Deriving Bmax from BWL

# %% [markdown]
# Based on the perfect correlation noted in the paper (Section 3.1), we use simple linear regression to derive Bmax from BWL.

# %%
# Features and target for Bmax prediction (Bmax ~ BWL)
X_bw = df[['Bwl']]
y_bw = df['Bmax']

# Split the data (75% training, 25% testing)
X_train_bw, X_test_bw, y_train_bw, y_test_bw = train_test_split(X_bw, y_bw, test_size=0.25, random_state=42)

# Train Linear Regression model
model_bw = LinearRegression()
model_bw.fit(X_train_bw, y_train_bw)

# Make predictions
y_pred_bw = model_bw.predict(X_test_bw)

# Evaluate the model
mse_bw = mean_squared_error(y_test_bw, y_pred_bw)
rmse_bw = sqrt(mse_bw)
mae_bw = mean_absolute_error(y_test_bw, y_pred_bw)
r2_bw = r2_score(y_test_bw, y_pred_bw)

# Output regression formula and metrics
print("Regression Formula for Bmax (derived from BWL):")
print(f"Bmax = {model_bw.intercept_:.2f} + ({model_bw.coef_[0]:.2f}) * Bwl\n")
print("Evaluation Results:")
print("MAE:", mae_bw)
print("MSE:", mse_bw)
print("RMSE:", rmse_bw)
print("R² Score:", r2_bw)
# Out:
# Regression Formula for Bmax (derived from BWL):
# Bmax = -0.05 + (1.18) * Bwl
#
# Evaluation Results:
# MAE: 0.006246074169744283
# MSE: 8.378088117996785e-05
# RMSE: 0.009153189672456692
# R² Score: 0.9990734464554148

# %% [markdown]
# # Regression 2 – Deriving D from T

# %% [markdown]
# Similarly, a linear regression is applied to derive Depth (D) from Draft (T), as highlighted in Section 3.1 of your paper.

# %%
# Features and target for D prediction (D ~ T)
X_dt = df[['T']]
y_dt = df['D']

# Split the data
X_train_dt, X_test_dt, y_train_dt, y_test_dt = train_test_split(X_dt, y_dt, test_size=0.25, random_state=42)

# Train Linear Regression model
model_dt = LinearRegression()
model_dt.fit(X_train_dt, y_train_dt)

# Make predictions
y_pred_dt = model_dt.predict(X_test_dt)

# Evaluate the model
mse_dt = mean_squared_error(y_test_dt, y_pred_dt)
rmse_dt = sqrt(mse_dt)
mae_dt = mean_absolute_error(y_test_dt, y_pred_dt)
r2_dt = r2_score(y_test_dt, y_pred_dt)

# Output regression formula and metrics
print("Regression Formula for D (derived from T):")
print(f"D = {model_dt.intercept_:.2f} + ({model_dt.coef_[0]:.2f}) * T\n")
print("Evaluation Results:")
print("MAE:", mae_dt)
print("MSE:", mse_dt)
print("RMSE:", rmse_dt)
print("R² Score:", r2_dt)
# Out:
# Regression Formula for D (derived from T):
# D = 1.15 + (1.00) * T
#
# Evaluation Results:
# MAE: 2.5953265510717945e-17
# MSE: 5.762782586841807e-33
# RMSE: 7.59129935310274e-17
# R² Score: 1.0

# %% [markdown]
# # Plotting Derived Regressions for Bmax and D

# %% [markdown]
# This cell plots the regression lines for both Bmax vs. BWL and D vs. T side by side. It visually confirms the perfect correlations noted in your study.

# %%
# Save parameters from the previous regressions
intercept_bw = model_bw.intercept_
coef_bw = model_bw.coef_[0]
intercept_dt = model_dt.intercept_
coef_dt = model_dt.coef_[0]

# Create subplots for both regressions
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Left Plot: Bmax vs. BWL
axes[0].scatter(df['Bwl'], df['Bmax'], color='blue', label='Data Points')
x_vals_bw = np.linspace(df['Bwl'].min(), df['Bwl'].max(), 100)
y_vals_bw = intercept_bw + coef_bw * x_vals_bw
axes[0].plot(x_vals_bw, y_vals_bw, color='red', linewidth=2, label='Regression Line')
axes[0].set_xlabel('Bwl')
axes[0].set_ylabel('Bmax')
axes[0].set_title('Regression: Bmax vs. Bwl')
axes[0].legend()
axes[0].grid(True)

# Right Plot: D vs. T
axes[1].scatter(df['T'], df['D'], color='green', label='Data Points')
x_vals_dt = np.linspace(df['T'].min(), df['T'].max(), 100)
y_vals_dt = intercept_dt + coef_dt * x_vals_dt
axes[1].plot(x_vals_dt, y_vals_dt, color='orange', linewidth=2, label='Regression Line')
axes[1].set_xlabel('T')
axes[1].set_ylabel('D')
axes[1].set_title('Regression: D vs. T')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Regression 3 – Predicting Displacement Using CatBoost

# %% [markdown]
# To capture the non-linear relationship for ship displacement (as detailed in Section 3.1), we use a CatBoost Regressor with features T, BWL, and LWL.

# %%
# Features and target for Displacement prediction
X_disp = df[['T', 'Bwl', 'Lwl']]
y_disp = df['D']  # 'D' is used as displacement in this context

# Split the data
X_train_disp, X_test_disp, y_train_disp, y_test_disp = train_test_split(X_disp, y_disp, test_size=0.25, random_state=42)

# Initialize and train the CatBoost Regressor
model_disp = CatBoostRegressor(iterations=500, learning_rate=0.1, depth=6, verbose=100)
model_disp.fit(X_train_disp, y_train_disp)

# Make predictions
y_pred_disp = model_disp.predict(X_test_disp)

# Evaluate the model
mse_disp = mean_squared_error(y_test_disp, y_pred_disp)
rmse_disp = sqrt(mse_disp)
mae_disp = mean_absolute_error(y_test_disp, y_pred_disp)
r2_disp = r2_score(y_test_disp, y_pred_disp)

# Custom rounding (as per research paper reporting)
def custom_round(x):
    return np.floor(x + 0.5)

print("CatBoost Regression (Displacement Prediction) Evaluation:")
print("MAE:", custom_round(mae_disp))
print("MSE:", custom_round(mse_disp))
print("RMSE:", custom_round(rmse_disp))
print("R² Score:", custom_round(r2_disp * 100), "%")

# Plot Actual vs. Predicted Displacement
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(y_test_disp, y_pred_disp, color='red', marker='x', label='Predicted vs Actual')
plt.plot([min(y_test_disp), max(y_test_disp)], [min(y_test_disp), max(y_test_disp)], color='blue', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Displacement (D)', fontsize=12)
plt.ylabel('Predicted Displacement (ŷ)', fontsize=12)
plt.title('CatBoost Regression: Actual vs Predicted Displacement', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# 0:	learn: 0.1069513	total: 169ms	remaining: 1m 24s
# 100:	learn: 0.0001353	total: 285ms	remaining: 1.13s
# 200:	learn: 0.0000008	total: 327ms	remaining: 486ms
# 300:	learn: 0.0000000	total: 367ms	remaining: 242ms
# 400:	learn: 0.0000000	total: 411ms	remaining: 102ms
# 499:	learn: 0.0000000	total: 459ms	remaining: 0us
# CatBoost Regression (Displacement Prediction) Evaluation:
# MAE: 0.0
# MSE: 0.0
# RMSE: 0.0
# R² Score: 100.0 %

# %% [markdown]
# # Regression 4 – Predicting Wetted Surface Area Using CatBoost

# %% [markdown]
# Following the paper’s methodology, wetted surface area (or water surface area) is predicted using a CatBoost model with inputs including LWL, BWL, T, and the previously predicted displacement.

# %%
# Features and target for Wetted Surface Area prediction
X_ws = df[['Lwl', 'Bwl', 'T', 'D']]
y_ws = df['wated_surface']

# Split the data
X_train_ws, X_test_ws, y_train_ws, y_test_ws = train_test_split(X_ws, y_ws, test_size=0.25, random_state=42)

# Initialize and train the CatBoost Regressor
model_ws = CatBoostRegressor(iterations=500, learning_rate=0.1, depth=6, verbose=100)
model_ws.fit(X_train_ws, y_train_ws)

# Make predictions
y_pred_ws = model_ws.predict(X_test_ws)

# Evaluate the model
mse_ws = mean_squared_error(y_test_ws, y_pred_ws)
rmse_ws = sqrt(mse_ws)
mae_ws = mean_absolute_error(y_test_ws, y_pred_ws)
r2_ws = r2_score(y_test_ws, y_pred_ws)

print("CatBoost Regression (Wetted Surface Area Prediction) Evaluation:")
print("MAE:", mae_ws)
print("MSE:", mse_ws)
print("RMSE:", rmse_ws)
print("R² Score:", r2_ws)

# Plot Actual vs. Predicted Wetted Surface Area
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(y_test_ws, y_pred_ws, color='red', marker='x', label='Predicted vs Actual')
plt.plot([min(y_test_ws), max(y_test_ws)], [min(y_test_ws), max(y_test_ws)], color='blue', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Wetted Surface Area', fontsize=12)
plt.ylabel('Predicted Wetted Surface Area', fontsize=12)
plt.title('CatBoost Regression: Actual vs Predicted Wetted Surface Area', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# 0:	learn: 1.8082334	total: 449us	remaining: 224ms
# 100:	learn: 0.0784921	total: 42.3ms	remaining: 167ms
# 200:	learn: 0.0782912	total: 80.3ms	remaining: 119ms
# 300:	learn: 0.0782912	total: 116ms	remaining: 76.6ms
# 400:	learn: 0.0782912	total: 153ms	remaining: 37.7ms
# 499:	learn: 0.0782912	total: 192ms	remaining: 0us
# CatBoost Regression (Wetted Surface Area Prediction) Evaluation:
# MAE: 0.039765086617267256
# MSE: 0.005276327571229335
# RMSE: 0.07263833403396126
# R² Score: 0.998768603933204

# %% [markdown]
# # Regression 5 – Predicting Midship Section Area (Ax) Using Linear Regression

# %% [markdown]
# As described in Section 3.1, a strong correlation between Ax, T, BWL, and Displacement allows a simple linear regression to predict the midship section area.

# %%
# Features and target for Ax prediction (Ax ~ BWL, T, Displacement)
X_ax = df[['Bwl', 'T', 'D']]
y_ax = df['Ax']

# Split the data
X_train_ax, X_test_ax, y_train_ax, y_test_ax = train_test_split(X_ax, y_ax, test_size=0.25, random_state=42)

# Train Linear Regression model
model_ax = LinearRegression()
model_ax.fit(X_train_ax, y_train_ax)

# Make predictions
y_pred_ax = model_ax.predict(X_test_ax)

# Evaluate the model
mse_ax = mean_squared_error(y_test_ax, y_pred_ax)
rmse_ax = sqrt(mse_ax)
mae_ax = mean_absolute_error(y_test_ax, y_pred_ax)
r2_ax = r2_score(y_test_ax, y_pred_ax)

# Plot Actual vs. Predicted Ax and output regression formula
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(y_test_ax, y_pred_ax, color='red', marker='x', label='Predicted vs Actual')
plt.plot([min(y_test_ax), max(y_test_ax)], [min(y_test_ax), max(y_test_ax)], color='blue', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Ax', fontsize=12)
plt.ylabel('Predicted Ax', fontsize=12)
plt.title('Linear Regression: Actual vs Predicted Ax', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

print("Regression Formula for Ax (Midship Section Area):")
print(f"Ax = {model_ax.intercept_:.2f} + ({model_ax.coef_[0]:.2f}) * Bwl + ({model_ax.coef_[1]:.2f}) * T + ({model_ax.coef_[2]:.2f}) * D")
print("\nEvaluation Metrics:")
print("MAE:", mae_ax)
print("MSE:", mse_ax)
print("RMSE:", rmse_ax)
print("R² Score:", r2_ax)
# Out:
# Regression Formula for Ax (Midship Section Area):
# Ax = -12511111033481.34 + (0.52) * Bwl + (-10879226985632.47) * T + (10879226985634.52) * D
#
# Evaluation Metrics:
# MAE: 0.013270089285714257
# MSE: 0.00026336043717025033
# RMSE: 0.016228383689395883
# R² Score: 0.9968173254971988

# %% [markdown]
# # Regression 6 – Predicting Waterplane Area (Aw) Using Linear Regression

# %% [markdown]
# Using inputs such as wetted surface area, Ax, BWL, and Displacement, a linear model is applied to predict the waterplane area, as outlined in Section 3.1.

# %%
# Features and target for Aw prediction (Aw ~ Wetted Surface, Ax, BWL, Displacement)
X_aw = df[['wated_surface', 'Ax', 'Bwl', 'D']]
y_aw = df['Aw']

# Split the data
X_train_aw, X_test_aw, y_train_aw, y_test_aw = train_test_split(X_aw, y_aw, test_size=0.25, random_state=42)

# Train Linear Regression model
model_aw = LinearRegression()
model_aw.fit(X_train_aw, y_train_aw)

# Make predictions
y_pred_aw = model_aw.predict(X_test_aw)

# Evaluate the model
mse_aw = mean_squared_error(y_test_aw, y_pred_aw)
rmse_aw = sqrt(mse_aw)
mae_aw = mean_absolute_error(y_test_aw, y_pred_aw)
r2_aw = r2_score(y_test_aw, y_pred_aw)

# Plot Actual vs. Predicted Aw and output regression formula
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(y_test_aw, y_pred_aw, color='red', marker='x', label='Predicted vs Actual')
plt.plot([min(y_test_aw), max(y_test_aw)], [min(y_test_aw), max(y_test_aw)], color='blue', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Aw', fontsize=12)
plt.ylabel('Predicted Aw', fontsize=12)
plt.title('Linear Regression: Actual vs Predicted Aw', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

print("Regression Formula for Aw (Waterplane Area):")
print(f"Aw = {model_aw.intercept_:.2f} + ({model_aw.coef_[0]:.2f}) * Wetted Surface + ({model_aw.coef_[1]:.2f}) * Ax + ({model_aw.coef_[2]:.2f}) * Bwl + ({model_aw.coef_[3]:.2f}) * D")
print("\nEvaluation Metrics:")
print("MAE:", mae_aw)
print("MSE:", mse_aw)
print("RMSE:", rmse_aw)
print("R² Score:", r2_aw)
# Out:
# Regression Formula for Aw (Waterplane Area):
# Aw = 11.42 + (0.98) * Wetted Surface + (0.65) * Ax + (0.65) * Bwl + (-9.00) * D
#
# Evaluation Metrics:
# MAE: 0.11631285925246816
# MSE: 0.0249102368154336
# RMSE: 0.15782977163841302
# R² Score: 0.9935879469193855

# %% [markdown]
# # Regression 7 – Predicting Longitudinal Center of Buoyancy (LCB) Using Gradient Boosting

# %% [markdown]
# Due to complex, non-linear dependencies, LCB is predicted using a Gradient Boosting Regressor. This aligns with the paper’s approach for modeling weakly correlated parameters.

# %%
# Features and target for LCB prediction
# (Including multiple hydrodynamic features as indicated in the research paper)
X_lcb = df[['Ax', 'Aw', 'wated_surface', 'D', 'Bwl', 'Lwl', 'displacement']]
y_lcb = df['LCB']

# Split the data
X_train_lcb, X_test_lcb, y_train_lcb, y_test_lcb = train_test_split(X_lcb, y_lcb, test_size=0.25, random_state=42)

# Train Gradient Boosting Regressor
model_lcb = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1, max_depth=6, random_state=42)
model_lcb.fit(X_train_lcb, y_train_lcb)

# Make predictions
y_pred_lcb = model_lcb.predict(X_test_lcb)

# Evaluate the model
mse_lcb = mean_squared_error(y_test_lcb, y_pred_lcb)
rmse_lcb = sqrt(mse_lcb)
mae_lcb = mean_absolute_error(y_test_lcb, y_pred_lcb)
r2_lcb = r2_score(y_test_lcb, y_pred_lcb)

# Plot Actual vs. Predicted LCB
plt.figure(figsize=(10, 6), dpi=300)
plt.scatter(y_test_lcb, y_pred_lcb, color='red', marker='x', label='Predicted vs Actual')
plt.plot([min(y_test_lcb), max(y_test_lcb)], [min(y_test_lcb), max(y_test_lcb)], color='blue', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual LCB', fontsize=12)
plt.ylabel('Predicted LCB', fontsize=12)
plt.title('Gradient Boosting: Actual vs Predicted LCB', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

print("Evaluation Metrics for LCB Prediction:")
print("MAE:", mae_lcb)
print("MSE:", mse_lcb)
print("RMSE:", rmse_lcb)
print("R² Score:", r2_lcb)

# Output feature importances for further insight
print("\nFeature Importances:")
for feature, importance in zip(X_lcb.columns, model_lcb.feature_importances_):
    print(f"{feature}: {importance:.4f}")
# Out:
# Evaluation Metrics for LCB Prediction:
# MAE: 1.2138570238373121e-08
# MSE: 2.2260943835129193e-16
# RMSE: 1.4920101821076555e-08
# R² Score: 0.9999999999999999
#
# Feature Importances:
# Ax: 0.0905
# Aw: 0.3263
# wated_surface: 0.3346
# D: 0.0518
# Bwl: 0.0867
# Lwl: 0.0414
# displacement: 0.0687

# %% [markdown]
# # Model Training & Evaluation for Resistance Prediction (Rr)

# %% [markdown]
# This cell uses GridSearchCV to optimize several machine learning models
# (RandomForest, XGBoost, LightGBM, CatBoost, SVM, AdaBoost) with an expanded
# hyperparameter grid. It performs 10-Fold Cross-Validation to evaluate each model,
# calculates error metrics (MAE, MSE, RMSE, R²), and visualizes the results.
# The approach mirrors the detailed model comparison and performance assessment
# described in the research paper.

# %%
# --- Load Data ---
df = pd.read_csv(r'C:\Users\poory\Desktop\New folder\yacht_hydro.csv')

# Define Features and Target (target is Rr, representing resistance)
X = df.drop(columns=['Rr'])
y = df['Rr']

# Setup 10-Fold Cross-Validation as described in the paper
cv = KFold(n_splits=10, shuffle=True, random_state=42)

# --- Define Models with Expanded Hyperparameter Grids ---
models = {
    'RandomForest': {
        'model': RandomForestRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 200, 300],
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4]
        }
    },
    'XGBoost': {
        'model': XGBRegressor(random_state=42, verbosity=0),
        'params': {
            'n_estimators': [100, 200, 300],
            'learning_rate': [0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7],
            'subsample': [0.8, 1],
            'colsample_bytree': [0.8, 1]
        }
    },
    'LightGBM': {
        'model': LGBMRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 200, 300],
            'learning_rate': [0.01, 0.05, 0.1],
            'max_depth': [-1, 10, 20],
            'num_leaves': [31, 50, 70]
        }
    },
    'CatBoost': {
        'model': CatBoostRegressor(random_state=42, verbose=0),
        'params': {
            'iterations': [100, 200, 300],
            'learning_rate': [0.01, 0.05, 0.1],
            'depth': [4, 6, 8],
            'l2_leaf_reg': [1, 3, 5]
        }
    },
    'SVM': {
        'model': SVR(),
        'params': {
            'C': [0.1, 1, 10, 100],
            'kernel': ['linear', 'rbf', 'poly'],
            'gamma': ['scale', 'auto'],
            'epsilon': [0.01, 0.1, 0.5]
        }
    },
    'AdaBoost': {
        'model': AdaBoostRegressor(random_state=42),
        'params': {
            'n_estimators': [50, 100, 200, 300],
            'learning_rate': [0.01, 0.05, 0.1, 0.5, 1],
            'loss': ['linear', 'square', 'exponential']
        }
    }
}

# --- Train and Evaluate Models with 10-Fold Cross-Validation ---
results = []
predictions = {}  # To store cross-validated predictions for each model

for name, config in models.items():
    print(f"\nTraining {name}...")
    grid = GridSearchCV(config['model'], config['params'], cv=cv, 
                        scoring='neg_mean_squared_error', n_jobs=-1)
    grid.fit(X, y)
    
    best_model = grid.best_estimator_
    y_pred = cross_val_predict(best_model, X, y, cv=cv)
    
    mae = mean_absolute_error(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    rmse = sqrt(mse)
    r2 = r2_score(y, y_pred)
    
    results.append({
        'Model': name,
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'R2': r2,
        'Best Params': grid.best_params_
    })
    
    predictions[name] = y_pred

# --- Display Results in Table ---
results_df = pd.DataFrame(results)
print("\nModel Comparison:\n")
print(results_df.sort_values(by='R2', ascending=False))

# --- Plot 1: Bar Charts of Evaluation Metrics ---
metrics = ['MAE', 'RMSE', 'R2']
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for i, metric in enumerate(metrics):
    axes[i].bar(results_df['Model'], results_df[metric], color='skyblue')
    axes[i].set_title(metric)
    axes[i].set_xlabel('Model')
    axes[i].set_ylabel(metric)
    axes[i].set_xticklabels(results_df['Model'], rotation=45)
plt.suptitle('Comparison of Evaluation Metrics Across Models', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# --- Plot 2: Scatter Plots of Actual vs. Predicted for Each Model ---
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()
for i, (name, y_pred) in enumerate(predictions.items()):
    axes[i].scatter(y, y_pred, color='red', marker='x', alpha=0.6, label='Predicted vs Actual')
    axes[i].plot([y.min(), y.max()], [y.min(), y.max()], color='blue', linestyle='--', label='Perfect Prediction')
    axes[i].set_title(name)
    axes[i].set_xlabel('Actual Rr')
    axes[i].set_ylabel('Predicted Rr')
    axes[i].legend()
plt.suptitle('Actual vs. Predicted Rr for All Models', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# Training RandomForest...
#
# Training XGBoost...
# C:\Users\poory\anaconda3\envs\gpu-use\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 1059 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\poory\anaconda3\envs\gpu-use\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\poory\anaconda3\envs\gpu-use\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
# ...
